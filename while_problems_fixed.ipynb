# %%
import builtins

# First 10 Even number

count = 1
i = 1
while count < 11:
    if i%2 == 0:
        print(i)
        count += 1
    i +=1

# %%
# Q2.First 10 Odd numbers

count = 1
i = 1
while count < 11:
    if i%2 != 0:
        print(i)
        count += 1
    i +=1

# %%
# Q3. First 10 Natural numbers

i=1
while i<11:
    print(i)
    i += 1

# %%
# Q4. First 10 Whole numbers

i=0
while i<10:
    print(i)
    i += 1

# %%
# Q5. Write a program to print first 10 integers and their squares using while loop.

i = 1
while i<11:
    print(i,end = ' ')
    # print(i*i)
    i += 1
print()           #for the next line.
j = 1
while j<11:
    print(j*j, end=' ')
    j +=1

# %%
# Q6. Write while loop statement to print the following series: 10, 20, 30 … … 300

i = 1
while i<31:
    print(10*i, end=' ')
    i +=1

# %%
# Q7. Write a while loop statement to print the following series 105, 98, 91 ………7.
i = 15
while i > 0:
    print(7*i, end=' ')
    i -= 1

# %%
# Q8. Write a program to print the first 10 natural number in reverse order using while loop.
i = 11
while i > 0:
    print(i, end=' ')
    i -= 1

# %%
# Q9. Write a program to print sum of first 10 Natural numbers
add = 0
i = 1
while i < 11:
    add += i
    i +=1
print(add)

# %%
# Q10. Write a program to print sum of first 10 Even numbers.
add_even = 0
count = 0
i = 2
while count < 10:
    if i % 2 == 0:
        count += 1
        add_even += i
    i += 1
print(add_even)

# %%
# Q11. Write a program to print table of a number entered from the user.

num = int(builtins.input('enter table: '))
i = 1
while i < 11:
    print(num*i, end=' ')
    i +=1

# %%
# Q12. Write a program to print all even numbers that falls between two numbers (exclusive both numbers) entered from the user using while loop.
print('make sure a < b')
a = int(builtins.input('Enter first number: '))
b = int(builtins.input('Enter second number: '))
a +=1
while a < b:
    if a % 2 == 0:
        print(a, end=' ')
    a +=1

# %%
# Q13. Write a program to check whether a number is prime or not using while loop.

num = int(builtins.input('Enter number to check whether it is prime or not: '))

if num < 2:
    print("Not Prime")
else:
    flag = True
    i = 2

    while i * i <= num:
        if num % i == 0:
            flag = False
            break
        i += 1

    if flag:
        print("Prime")
    else:
        print("Not Prime")

# %%
# Q17. Write a program to display the number names of the digits of a number entered by user,
# for example if the number is 231 then output should be Two Three One

d = {
    0: 'zero', 1: 'one', 2: 'two', 3: 'three', 4: 'four',
    5: 'five', 6: 'six', 7: 'seven', 8: 'eight', 9: 'nine'
}

num = int(builtins.input('Enter the number: '))
out = ''

if num == 0:
    out = d[0]
else:
    while num > 0:
        digit = num % 10
        out = d[digit] + ' ' + out
        num //= 10

print(out)

# %%
# Q21. 
# Write a program to add first n terms of the following series using a while loop:
# 1/1! + 1/2! + 1/3! + …….. + 1/n!

num = int(builtins.input('enter no: '))
i = 1
add = 0
fact = 1

while i <= num:
    fact = i*fact
    add += 1/fact
    i += 1

print(add)

# %%
# Q21. Sum of series: 1/1! + 1/2! + ... + 1/n!

n = int(builtins.input("Enter n: "))
i = 1
fact = 1
s = 0
while i <= n:
    fact *= i
    s += 1 / fact
    i += 1
print("Sum =", s)

# %%
# Q22. Enter numbers until user wants, then display sum

total = 0
choice = "y"

while choice.lower() == "y":
    num = int(builtins.input("Enter number: "))
    total += num
    choice = builtins.input("Continue? (y/n): ")

print("Sum =", total)

# %%
# Q23. Count positive and negative numbers until 0 is entered

pos = 0
neg = 0

while True:
    num = int(builtins.input("Enter number (0 to stop): "))
    if num == 0:
        break
    elif num > 0:
        pos += 1
    else:
        neg += 1

print("Positive =", pos)
print("Negative =", neg)

# %%
# Q24. HCF of two numbers

a = int(builtins.input("Enter first number: "))
b = int(builtins.input("Enter second number: "))

while b != 0:
    a, b = b, a % b

print("HCF =", a)

# %%
# Q25. Decimal to Binary

n = int(builtins.input("Enter decimal number: "))

if n == 0:
    binary = "0"
else:
    binary = ""
    while n > 0:
        binary = str(n % 2) + binary
        n //= 2

print("Binary =", binary)

# %%
# Q26. Binary to Decimal

binary = builtins.input("Enter binary number: ")
i = len(binary) - 1
power = 0
decimal = 0

while i >= 0:
    decimal += int(binary[i]) * (2 ** power)
    power += 1
    i -= 1

print("Decimal =", decimal)

# %%
# Q27. Palindrome number

n = int(builtins.input("Enter number: "))
temp = n
rev = 0

while temp > 0:
    rev = rev * 10 + temp % 10
    temp //= 10

if n == rev:
    print("Palindrome")
else:
    print("Not Palindrome")

# %%
# Q28. Sum: 1 + 1/1! + 1/2! + ... + 1/n!

n = int(builtins.input("Enter n: "))
i = 1
fact = 1
s = 1

while i <= n:
    fact *= i
    s += 1 / fact
    i += 1

print("Sum =", s)

# %%
# Q29. Average of 10 numbers

i = 1
total = 0

while i <= 10:
    num = int(builtins.input("Enter number: "))
    total += num
    i += 1

print("Average =", total / 10)

# %%
# Q30. Largest and smallest among 10 numbers

i = 1
num = int(builtins.input("Enter number: "))
largest = smallest = num

while i < 10:
    num = int(builtins.input("Enter number: "))
    if num > largest:
        largest = num
    if num < smallest:
        smallest = num
    i += 1

print("Largest =", largest)
print("Smallest =", smallest)

# %%
# Q31. Sum of odd and even numbers between two numbers

a = int(builtins.input("Enter first number: "))
b = int(builtins.input("Enter second number: "))

even_sum = 0
odd_sum = 0

while a <= b:
    if a % 2 == 0:
        even_sum += a
    else:
        odd_sum += a
    a += 1

print("Even Sum =", even_sum)
print("Odd Sum =", odd_sum)

# %%
# Q32. Numbers divisible by 13 but not by 3 (100 to 500)

i = 101

while i < 500:
    if i % 13 == 0 and i % 3 != 0:
        print(i)
    i += 1

# %%
# Q33. Series: 2, 22, 222, ...

n = int(builtins.input("Enter n: "))
i = 1
term = 0

while i <= n:
    term = term * 10 + 2
    print(term)
    i += 1

# %%
# Q33. Series: 2, 22, 222, ...

n = int(builtins.input("Enter n: "))
i = 1
term = 0

while i <= n:
    term = term * 10 + 2
    print(term)
    i += 1

# %%
# Q34. Series: 1, 4, 9, 16, ...

n = int(builtins.input("Enter n: "))
i = 1

while i <= n:
    print(i * i)
    i += 1

# %%
# Q35. Sum: 1 + x/1! + x²/2! + ... + xⁿ/n!

x = int(builtins.input("Enter x: "))
n = int(builtins.input("Enter n: "))

i = 1
fact = 1
s = 1

while i <= n:
    fact *= i
    s += (x ** i) / fact
    i += 1

print("Sum =", s)

# %%
# Q36. Sum: x + x²/2 + ... + xⁿ/n

x = int(builtins.input("Enter x: "))
n = int(builtins.input("Enter n: "))

i = 1
s = 0

while i <= n:
    s += (x ** i) / i
    i += 1

print("Sum =", s)

# %%
# Q37. Sum: 1 + 8 + 27 + ... n terms

n = int(builtins.input("Enter n: "))
i = 1
s = 0

while i <= n:
    s += i ** 3
    i += 1

print("Sum =", s)

# %%
# Q38. Sum: 1 + 2 + 6 + 24 + 120 + ...

n = int(builtins.input("Enter n: "))
i = 1
fact = 1
s = 0

while i <= n:
    fact *= i
    s += fact
    i += 1

print("Sum =", s)

# %%
# Q39. Sum: 1 - 4 + 9 - 16 + 25 ...

n = int(builtins.input("Enter n: "))
i = 2
s = 1

while i <= n:
    if i % 2 == 0:
        s -= i * i
    else:
        s += i * i
    i += 1

print("Sum =", s)

# %%
# Q40. Print all characters of "PYTHON"

s = "PYTHON"
i = 0

while i < len(s):
    print(s[i])
    i += 1

# %%
# Q43. Write a python program to get the following output
# 1—–49
# 2—–48
# 3—–47
# …
# …
# 48—–2
# 49—–1


i = 1
while i< 50:
    print(i,'-----',50-i)
    i += 1

# %%
# Q60.Write a program to get the following output
# input='hai hello good morning'
# output={‘hai’:’a’ , ‘hello’: ‘l’ , ‘good’:’gd’ , ‘morning’:’n’}

st='hai hello good morning'
word = st.split()
i = 0
d={}
while i < len(word):
    w = word[i]
    if len(w) % 2 == 0:
        d[w] = w[0] + w[-1]
    else:
        middle = len(w)//2
        d[w] = w[middle]
    i += 1
print(d)

# %%
# Q69.Program to find the length of the longest substring without repeating characters in a given string using while loop

# %%
n = int(input("enter a number: "))
while n > 0:
    print('Thank you.')
    n -= 1
# Out:
# Thank you.
# Thank you.
# Thank you.
# Thank you.
# Thank you.

# %%
# Q99. Write a program for number game

actual_num = 20
guess = int(input("Guess the number: "))

while guess != actual_num:
    if guess < actual_num:
        print("Too low!")
    else:
        print("Too high!")
    guess = int(input("Try again: "))

print("Correct! You guessed the number.")
# Out:
# Too low!
# Too high!
# Correct! You guessed the number.

# %%
# Q98.Write a program to reverse the given list
num = eval(input("give a list: "))
print(num[::-1])
# Out:
# [4, 3, 2, 1]

# %%
#Q97.Write a program to get the following output - 
# Input='hai hello how are you' 
# output='hai**hello**how**are**you'
a=input('Enter string : ')
out=''
i=0
while i < len(a):
    if a[i]!= ' ':
      print(a[i],end='') 
    
    else:
       print('**',end='')
    i+=1
# Out:
# 'hai**hello**how**are**you'
