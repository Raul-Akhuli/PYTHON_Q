# %%
#me
s = eval(input('enter a collection: '))
out = {}
word = ''
reverse = ''
even_pas = ''
count = 0
idx = 0

for i in s:
    for idx, j in enumerate(i):
        if j != ' ':
            word += j
            reverse = j + reverse
            if j in 'aeiouAEIOU':
                count += 1
            if idx %2 == 0:
                even_pas += j
        else:
            out[word] = [reverse, count, even_pas]
            reverse = ''
            even_pas = ''
            word = ''
            count = 0
            idx = 0
    out[word] = [reverse, count, even_pas]
    reverse = ''
    even_pas = ''
    word = ''
    
print(out)
# Out:
# {'Hello': ['olleH', 2, 'Hlo'], 'World': ['dlroW', 1, 'Wrd']}

# %%
# diya
a = eval(input('enter collection: '))
out = {}
rev = ''
count = 0
index = ''

for i in a.split():
    for j in i:
        out += i
        rev = i + rev
    li = rev
    z = 0
    while z < len(li):
        if li in 'aeiouAEIOU':
            count +=1
            index = li[i]
        i += 1

# %%
s = eval(input('enter collection: '))
out = {}
for i in s.split():
    count = 0
    even = ''
    for j in range(len(i)):
        if i[j] in 'aeiouAEIOU':
            count += 1
        if j%2 == 0:
            even += i[j]

    out[i] = [i[::-1],count,even]

# %%
# integrate me with mam logic
s = eval(input('enter a collection: '))
out = {}
word = ''
reverse = ''
even_pas = ''
count = 0
idx = 0

for i in s:
    for idx, j in enumerate(i):
        if j != ' ':
            word += j
            reverse = j + reverse
            if j in 'aeiouAEIOU':
                count += 1
            if idx %2 == 0:
                even_pas += j
        else:
            out[word] = [reverse, count, even_pas]
            reverse = ''
            even_pas = ''
            word = ''
            count = 0
            idx = 0
    out[word] = [reverse, count, even_pas]
    reverse = ''
    even_pas = ''
    word = ''
    
print(out)

# %%
# ip = [100,200,35,40,60]
# out = [335,235,400,395,375]

# %%
# In = 'bacbcaabbaa'
# out = 'b4a5c2'

st = input('enter string: ')
out = ''
d = {}
for i in st:
    if i in d:
        d[i] += 1
    else:
        d[i] = 1
for i in d:
    out += i + str(d[i])
print(out)
# Out:
# b4a5c2

# %%
num = int(input('enter number: '))
temp = num
sum = 0
while num > 0:
    digit = num%10
    product = 1
    while digit >=1:
        product *= digit
        digit -= 1
    num = num //10
    sum += product
if sum == temp:
    print('strong number.')
else:
    print('not a strong number.')
# Out:
# strong number.

# %%
# Wap to get the following output.
# In={10:'star',20:'bye',30:'moon',40:'apple'}
# Out={10:'a',20:'e',30:'oo',40:'ae'}


col = eval(input('enter collection: '))
out = {}
word = ''
for i in col:
    vowle = ''
    word = col[i]
    for ch in word:
        if ch in 'aeiouAEIOU':
            vowle += ch
    out[i] = vowle

print(out)
# Out:
# {10: 'a', 20: 'e', 30: 'oo', 40: 'ae'}

# %%
# 117
# Wap to get the following output
# In=[100,200,50,400,300]
# N=300
# Out=[[100,200],[300]]


# col = eval(input('enter collection: '))
# n = int(input('enter number: '))
# num = set()
# out = []
# for i in col:
#     rem = n - i
#     if i not in num:
#         if rem in col:
#             num.add(i)
#             num.add(rem)
#             out.append(list(num))
#             out.append(n)

# print(out)



a = eval(input('enter collection: '))
target = int(input('enter target value: '))
out = []

for i in range (len(a)):
    if a[i] == target:
        out.append([a[i]])
        for j in range (i+1, len(a)):
            if a[i] + a[j] == target:
                out.append([a[i],a[j]])
print(out)
# Out:
# []

# %%
# 120. 
# Wap to get the following output.
# In=[‘hello’,227,3.4,’last’,189,34]
# Out=[722,981,43]


col = eval(input('enter collection: '))
