# %%
# xylem number
##1234
##1+4 == 3+2

num = int(input('enter a number: '))
st = str(num)
n = len(st)
i = 0
sum1 = 0
sum2 = 0

if n > 3:
    while num >0:
        if n == 1 or n == len(st):
            digit = num%10
            sum1 += digit
        else:
            digit = num%10
            sum2 += num
        n = n//10
else:
    print('not a xylam number.')

if sum1 == sum2:
    print('xylam number.')
